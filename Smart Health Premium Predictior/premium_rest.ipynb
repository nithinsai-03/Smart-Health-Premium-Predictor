# %%
import pandas as pd

# %%
df=pd.read_excel("premiums_rest.xlsx")
df
# Out:
#        Age  Gender     Region Marital_status  Number Of Dependants  \
# 0       49  Female  Northeast        Married                     2
# 1       56    Male  Northeast        Married                     3
# 2       33    Male  Southeast        Married                     3
# 3       43    Male  Northeast        Married                     3
# 4       59  Female  Southeast      Unmarried                     0
# ...    ...     ...        ...            ...                   ...
# 25297   60  Female  Northwest        Married                     3
# 25298   40  Female  Southeast      Unmarried                     0
# 25299   37  Female  Northwest      Unmarried                     0
# 25300   47  Female  Southeast        Married                     2
# 25301   48  Female  Southwest        Married                     3
#
#       BMI_Category Smoking_Status Employment_Status Income_Level  \
# 0           Normal     No Smoking     Self-Employed    10L - 25L
# 1          Obesity     Occasional     Self-Employed    10L - 25L
# 2           Normal        Regular     Self-Employed         <10L
# 3       Overweight        Regular          Salaried        > 40L
# 4       Overweight     No Smoking        Freelancer    10L - 25L
# ...            ...            ...               ...          ...
# 25297       Normal     No Smoking     Self-Employed    25L - 40L
# 25298   Overweight        Regular          Salaried    10L - 25L
# 25299      Obesity     No Smoking          Salaried         <10L
# 25300       Normal     No Smoking          Salaried        > 40L
# 25301       Normal     Occasional     Self-Employed         <10L
#
#        Income_Lakhs                 Medical History Insurance_Plan  \
# 0                20             High blood pressure         Silver
# 1                14                        Diabetes         Bronze
# 2                 4  Diabetes & High blood pressure         Silver
# 3                46                         Thyroid           Gold
# 4                21                      No Disease           Gold
# ...             ...                             ...            ...
# 25297            26             High blood pressure           Gold
# 25298            16              Diabetes & Thyroid           Gold
# 25299             4                      No Disease         Bronze
# 25300            82                         Thyroid           Gold
# 25301             7                        Diabetes         Silver
#
#        Annual_Premium_Amount
# 0                      18164
# 1                      15610
# 2                      20653
# 3                      26926
# 4                      26101
# ...                      ...
# 25297                  26370
# 25298                  29496
# 25299                  10957
# 25300                  27076
# 25301                  19730
#
# [25302 rows x 13 columns]

# %%
df.shape
# Out:
# (25302, 13)

# %%
df.columns.str.replace(' ','_').str.lower
df.head(1)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0  High blood pressure         Silver                  18164

# %%
df.head(1)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0  High blood pressure         Silver                  18164

# %%
df.columns.str.replace('Number Of Dependants','No_of_dependents')
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'No_of_dependents',
#        'BMI_Category', 'Smoking_Status', 'Employment_Status', 'Income_Level',
#        'Income_Lakhs', 'Medical History', 'Insurance_Plan',
#        'Annual_Premium_Amount'],
#       dtype='object')

# %%
df.columns.str.replace('Medical History','Medical_history')
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'Number Of Dependants',
#        'BMI_Category', 'Smoking_Status', 'Employment_Status', 'Income_Level',
#        'Income_Lakhs', 'Medical_history', 'Insurance_Plan',
#        'Annual_Premium_Amount'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
# 1   56    Male  Northeast        Married                     3      Obesity
# 2   33    Male  Southeast        Married                     3       Normal
# 3   43    Male  Northeast        Married                     3   Overweight
# 4   59  Female  Southeast      Unmarried                     0   Overweight
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
# 1     Occasional     Self-Employed    10L - 25L            14
# 2        Regular     Self-Employed         <10L             4
# 3        Regular          Salaried        > 40L            46
# 4     No Smoking        Freelancer    10L - 25L            21
#
#                   Medical History Insurance_Plan  Annual_Premium_Amount
# 0             High blood pressure         Silver                  18164
# 1                        Diabetes         Bronze                  15610
# 2  Diabetes & High blood pressure         Silver                  20653
# 3                         Thyroid           Gold                  26926
# 4                      No Disease           Gold                  26101

# %% [markdown]
# Handling N/A Values

# %%
df.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Region                   0
# Marital_status           0
# Number Of Dependants     0
# BMI_Category             0
# Smoking_Status           8
# Employment_Status        1
# Income_Level             7
# Income_Lakhs             0
# Medical History          0
# Insurance_Plan           0
# Annual_Premium_Amount    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (25287, 13)

# %%
df.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Region                   0
# Marital_status           0
# Number Of Dependants     0
# BMI_Category             0
# Smoking_Status           0
# Employment_Status        0
# Income_Level             0
# Income_Lakhs             0
# Medical History          0
# Insurance_Plan           0
# Annual_Premium_Amount    0
# dtype: int64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 Age  Number Of Dependants  Income_Lakhs  Annual_Premium_Amount
# count  25287.000000          25287.000000  25287.000000           25287.000000
# mean      46.190968              2.384980     23.541227           21448.568276
# std       12.708209              1.421121     25.199278            7032.832294
# min       31.000000             -3.000000      1.000000            3625.000000
# 25%       38.000000              1.000000      7.000000           16049.000000
# 50%       45.000000              3.000000     17.000000           21079.000000
# 75%       54.000000              3.000000     32.000000           26931.000000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# outliers in no.of dependencies

# %%
a=df[df['Number Of Dependants']<0]
a.shape
# Out:
# (43, 13)

# %%
df['Number Of Dependants']=abs(df['Number Of Dependants'])

# %%
b=df[df['Number Of Dependants']<0]
b.shape
# Out:
# (0, 13)

# %%
df['Number Of Dependants'].describe()
# Out:
# count    25287.000000
# mean         2.390912
# std          1.411118
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          3.000000
# max          5.000000
# Name: Number Of Dependants, dtype: float64

# %%
df.describe()
# Out:
#                 Age  Number Of Dependants  Income_Lakhs  Annual_Premium_Amount
# count  25287.000000          25287.000000  25287.000000           25287.000000
# mean      46.190968              2.390912     23.541227           21448.568276
# std       12.708209              1.411118     25.199278            7032.832294
# min       31.000000              0.000000      1.000000            3625.000000
# 25%       38.000000              1.000000      7.000000           16049.000000
# 50%       45.000000              3.000000     17.000000           21079.000000
# 75%       54.000000              3.000000     32.000000           26931.000000
# max      356.000000              5.000000    930.000000           43471.000000

# %%
numeric_columns=df.select_dtypes(['Float64','Int64']).columns
numeric_columns
# Out:
# Index(['Age', 'Number Of Dependants', 'Income_Lakhs', 'Annual_Premium_Amount'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_columns
# Out:
# Index(['Age', 'Number Of Dependants', 'Income_Lakhs', 'Annual_Premium_Amount'], dtype='object')

# %%
for col in numeric_columns:
    sns.boxplot(x=df[col])
    plt.show()

# %%
df[df.Age>100]['Age'].unique()
# Out:
# array([224, 124, 136, 203, 356])

# %%
df1=df[df.Age<100].copy()

# %%
df1.describe()
# Out:
#                 Age  Number Of Dependants  Income_Lakhs  Annual_Premium_Amount
# count  25229.000000          25229.000000  25229.000000           25229.000000
# mean      45.841849              2.393119     23.550319           21461.193230
# std        9.740047              1.410496     25.212938            7022.353803
# min       31.000000              0.000000      1.000000            6538.000000
# 25%       38.000000              1.000000      7.000000           16057.000000
# 50%       45.000000              3.000000     17.000000           21087.000000
# 75%       54.000000              3.000000     32.000000           26931.000000
# max       72.000000              5.000000    930.000000           43471.000000

# %%
quantile_threshold=df1.Income_Lakhs.quantile(0.999)
quantile_threshold
# Out:
# np.float64(100.0)

# %%
df2=df1[df1.Income_Lakhs<=quantile_threshold].copy()

# %%
df2.Income_Lakhs.describe()
# Out:
# count    25223.000000
# mean        23.378702
# std         22.530266
# min          1.000000
# 25%          7.000000
# 50%         17.000000
# 75%         32.000000
# max        100.000000
# Name: Income_Lakhs, dtype: float64

# %%
df2.shape
# Out:
# (25223, 13)

# %%
for col in numeric_columns:
    sns.histplot(df2[col])
    plt.show()

# %%
df2.head(1)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0  High blood pressure         Silver                  18164

# %%
sns.scatterplot(df2,x='Age',y='Annual_Premium_Amount')
# Out:
# <Axes: xlabel='Age', ylabel='Annual_Premium_Amount'>

# %%
numeric_columns
# Out:
# Index(['Age', 'Number Of Dependants', 'Income_Lakhs', 'Annual_Premium_Amount'], dtype='object')

# %%
numeric_features=['Age', 'Number Of Dependants', 'Income_Lakhs']
for col in numeric_features:
    sns.scatterplot(df2,x=col,y=df2['Annual_Premium_Amount'])
    plt.show()

# %%
df2.head(5)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
# 1   56    Male  Northeast        Married                     3      Obesity
# 2   33    Male  Southeast        Married                     3       Normal
# 3   43    Male  Northeast        Married                     3   Overweight
# 4   59  Female  Southeast      Unmarried                     0   Overweight
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
# 1     Occasional     Self-Employed    10L - 25L            14
# 2        Regular     Self-Employed         <10L             4
# 3        Regular          Salaried        > 40L            46
# 4     No Smoking        Freelancer    10L - 25L            21
#
#                   Medical History Insurance_Plan  Annual_Premium_Amount
# 0             High blood pressure         Silver                  18164
# 1                        Diabetes         Bronze                  15610
# 2  Diabetes & High blood pressure         Silver                  20653
# 3                         Thyroid           Gold                  26926
# 4                      No Disease           Gold                  26101

# %%
df2.head(1)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0  High blood pressure         Silver                  18164

# %%
categorial_columns=['Gender','Region','Marital_status','BMI_Category','Smoking_Status','Employment_Status','Income_Level','Medical History','Insurance_Plan']
for col in categorial_columns:
    print(col,": ",df2[col].unique())
# Out:
# Gender :  ['Female' 'Male']
# Region :  ['Northeast' 'Southeast' 'Southwest' 'Northwest']
# Marital_status :  ['Married' 'Unmarried']
# BMI_Category :  ['Normal' 'Obesity' 'Overweight' 'Underweight']
# Smoking_Status :  ['No Smoking' 'Occasional' 'Regular' 'Does Not Smoke' 'Not Smoking'
#  'Smoking=0']
# Employment_Status :  ['Self-Employed' 'Salaried' 'Freelancer']
# Income_Level :  ['10L - 25L' '<10L' '> 40L' '25L - 40L']
# Medical History :  ['High blood pressure' 'Diabetes' 'Diabetes & High blood pressure'
#  'Thyroid' 'No Disease' 'Heart disease' 'Diabetes & Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid']
# Insurance_Plan :  ['Silver' 'Bronze' 'Gold']

# %%
df2['Smoking_Status'].replace({
    'Smoking=0':'No Smoking',
    'Does Not Smoke':'No Smoking',
    'Not Smoking':'No Smoking'
    
},inplace=True)
# Out:
# /var/folders/qq/hz97qkm52cxb4wthmb24ntsm0000gn/T/ipykernel_40324/3055924117.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Smoking_Status'].replace({

# %%
categorial_columns=['Gender','Region','Marital_status','BMI_Category','Smoking_Status','Employment_Status','Income_Level','Medical History','Insurance_Plan']
for col in categorial_columns:
    print(col,": ",df2[col].unique())
# Out:
# Gender :  ['Female' 'Male']
# Region :  ['Northeast' 'Southeast' 'Southwest' 'Northwest']
# Marital_status :  ['Married' 'Unmarried']
# BMI_Category :  ['Normal' 'Obesity' 'Overweight' 'Underweight']
# Smoking_Status :  ['No Smoking' 'Occasional' 'Regular']
# Employment_Status :  ['Self-Employed' 'Salaried' 'Freelancer']
# Income_Level :  ['10L - 25L' '<10L' '> 40L' '25L - 40L']
# Medical History :  ['High blood pressure' 'Diabetes' 'Diabetes & High blood pressure'
#  'Thyroid' 'No Disease' 'Heart disease' 'Diabetes & Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid']
# Insurance_Plan :  ['Silver' 'Bronze' 'Gold']

# %%
pct_count=df2['Gender'].value_counts(normalize=True)

# %%
for i in categorial_columns:
    sns.countplot(data=df2, x=i)
    plt.title(f"Count of {i}")
    plt.show()

# %% [markdown]
# FEATURE ENGINEERING

# %%
df2.sample(1)
# Out:
#        Age  Gender     Region Marital_status  Number Of Dependants  \
# 12997   42  Female  Southeast        Married                     2
#
#       BMI_Category Smoking_Status Employment_Status Income_Level  \
# 12997  Underweight        Regular          Salaried        > 40L
#
#        Income_Lakhs      Medical History Insurance_Plan  Annual_Premium_Amount
# 12997            49  High blood pressure           Gold                  25309

# %%
df2['Medical History'].unique()
# Out:
# array(['High blood pressure', 'Diabetes',
#        'Diabetes & High blood pressure', 'Thyroid', 'No Disease',
#        'Heart disease', 'Diabetes & Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid'],
#       dtype=object)

# %%
risk_score={
    'diabetes': 6,
    'heart disease' : 8,
    'thyroid': 5,
    'no disease': 0,
    'none': 0
}

# %%
df2[['disease1','disease2']]=df2['Medical History'].str.split("&",expand=True).apply(lambda x:x.str.lower())

# %%
df2['disease1'].fillna('none',inplace=True)
df2['disease2'].fillna('none',inplace=True)
df2['total_risk_score']=0


for disease in ['disease1','disease2']:
    df2['total_risk_score']+=df2[disease].map(risk_score)


max_score=df2['total_risk_score'].max()
min_score=df2['total_risk_score'].min()
df2['normalized_score']= (df2['total_risk_score']-min_score)/(max_score-min_score)
df2.head(5)
# Out:
# /var/folders/qq/hz97qkm52cxb4wthmb24ntsm0000gn/T/ipykernel_40324/1908823310.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['disease1'].fillna('none',inplace=True)
# /var/folders/qq/hz97qkm52cxb4wthmb24ntsm0000gn/T/ipykernel_40324/1908823310.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['disease2'].fillna('none',inplace=True)
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   49  Female  Northeast        Married                     2       Normal
# 1   56    Male  Northeast        Married                     3      Obesity
# 2   33    Male  Southeast        Married                     3       Normal
# 3   43    Male  Northeast        Married                     3   Overweight
# 4   59  Female  Southeast      Unmarried                     0   Overweight
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking     Self-Employed    10L - 25L            20
# 1     Occasional     Self-Employed    10L - 25L            14
# 2        Regular     Self-Employed         <10L             4
# 3        Regular          Salaried        > 40L            46
# 4     No Smoking        Freelancer    10L - 25L            21
#
#                   Medical History Insurance_Plan  Annual_Premium_Amount  \
# 0             High blood pressure         Silver                  18164
# 1                        Diabetes         Bronze                  15610
# 2  Diabetes & High blood pressure         Silver                  20653
# 3                         Thyroid           Gold                  26926
# 4                      No Disease           Gold                  26101
#
#               disease1              disease2  total_risk_score  \
# 0  high blood pressure                  none               NaN
# 1             diabetes                  none               6.0
# 2            diabetes    high blood pressure               NaN
# 3              thyroid                  none               5.0
# 4           no disease                  none               0.0
#
#    normalized_score
# 0               NaN
# 1             0.750
# 2               NaN
# 3             0.625
# 4             0.000

# %%
df2
# Out:
#        Age  Gender     Region Marital_status  Number Of Dependants  \
# 0       49  Female  Northeast        Married                     2
# 1       56    Male  Northeast        Married                     3
# 2       33    Male  Southeast        Married                     3
# 3       43    Male  Northeast        Married                     3
# 4       59  Female  Southeast      Unmarried                     0
# ...    ...     ...        ...            ...                   ...
# 25297   60  Female  Northwest        Married                     3
# 25298   40  Female  Southeast      Unmarried                     0
# 25299   37  Female  Northwest      Unmarried                     0
# 25300   47  Female  Southeast        Married                     2
# 25301   48  Female  Southwest        Married                     3
#
#       BMI_Category Smoking_Status Employment_Status Income_Level  \
# 0           Normal     No Smoking     Self-Employed    10L - 25L
# 1          Obesity     Occasional     Self-Employed    10L - 25L
# 2           Normal        Regular     Self-Employed         <10L
# 3       Overweight        Regular          Salaried        > 40L
# 4       Overweight     No Smoking        Freelancer    10L - 25L
# ...            ...            ...               ...          ...
# 25297       Normal     No Smoking     Self-Employed    25L - 40L
# 25298   Overweight        Regular          Salaried    10L - 25L
# 25299      Obesity     No Smoking          Salaried         <10L
# 25300       Normal     No Smoking          Salaried        > 40L
# 25301       Normal     Occasional     Self-Employed         <10L
#
#        Income_Lakhs                 Medical History Insurance_Plan  \
# 0                20             High blood pressure         Silver
# 1                14                        Diabetes         Bronze
# 2                 4  Diabetes & High blood pressure         Silver
# 3                46                         Thyroid           Gold
# 4                21                      No Disease           Gold
# ...             ...                             ...            ...
# 25297            26             High blood pressure           Gold
# 25298            16              Diabetes & Thyroid           Gold
# 25299             4                      No Disease         Bronze
# 25300            82                         Thyroid           Gold
# 25301             7                        Diabetes         Silver
#
#        Annual_Premium_Amount             disease1              disease2  \
# 0                      18164  high blood pressure                  none
# 1                      15610             diabetes                  none
# 2                      20653            diabetes    high blood pressure
# 3                      26926              thyroid                  none
# 4                      26101           no disease                  none
# ...                      ...                  ...                   ...
# 25297                  26370  high blood pressure                  none
# 25298                  29496            diabetes                thyroid
# 25299                  10957           no disease                  none
# 25300                  27076              thyroid                  none
# 25301                  19730             diabetes                  none
#
#        total_risk_score  normalized_score
# 0                   NaN               NaN
# 1                   6.0             0.750
# 2                   NaN               NaN
# 3                   5.0             0.625
# 4                   0.0             0.000
# ...                 ...               ...
# 25297               NaN               NaN
# 25298               NaN               NaN
# 25299               0.0             0.000
# 25300               5.0             0.625
# 25301               6.0             0.750
#
# [25223 rows x 17 columns]

# %%
df2['total_risk_score'].fillna('0.0',inplace=True)
# Out:
# /var/folders/qq/hz97qkm52cxb4wthmb24ntsm0000gn/T/ipykernel_40324/939485161.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['total_risk_score'].fillna('0.0',inplace=True)
# /var/folders/qq/hz97qkm52cxb4wthmb24ntsm0000gn/T/ipykernel_40324/939485161.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2['total_risk_score'].fillna('0.0',inplace=True)

# %%
df2.sample(5)
# Out:
#        Age  Gender     Region Marital_status  Number Of Dependants  \
# 7471    33  Female  Northwest      Unmarried                     0
# 15897   36    Male  Southeast        Married                     3
# 11080   49  Female  Southwest        Married                     2
# 7105    34    Male  Southeast        Married                     3
# 10651   47  Female  Northwest      Unmarried                     0
#
#       BMI_Category Smoking_Status Employment_Status Income_Level  \
# 7471       Obesity     No Smoking     Self-Employed    25L - 40L
# 15897       Normal     Occasional          Salaried        > 40L
# 11080      Obesity     No Smoking          Salaried         <10L
# 7105   Underweight        Regular     Self-Employed    25L - 40L
# 10651       Normal     Occasional          Salaried    10L - 25L
#
#        Income_Lakhs      Medical History Insurance_Plan  \
# 7471             27              Thyroid         Silver
# 15897            49              Thyroid         Bronze
# 11080             5  High blood pressure         Silver
# 7105             26  High blood pressure         Silver
# 10651            21           No Disease           Gold
#
#        Annual_Premium_Amount             disease1 disease2 total_risk_score  \
# 7471                   20066              thyroid     none              5.0
# 15897                  10241              thyroid     none              5.0
# 11080                  22302  high blood pressure     none              0.0
# 7105                   19122  high blood pressure     none              0.0
# 10651                  25214           no disease     none              0.0
#
#        normalized_score
# 7471              0.625
# 15897             0.625
# 11080               NaN
# 7105                NaN
# 10651             0.000

# %%
df2['Insurance_Plan']=df2['Insurance_Plan'].map({'Bronze':1,'Silver': 2,'Gold':3})

# %%
df2
# Out:
#        Age  Gender     Region Marital_status  Number Of Dependants  \
# 0       49  Female  Northeast        Married                     2
# 1       56    Male  Northeast        Married                     3
# 2       33    Male  Southeast        Married                     3
# 3       43    Male  Northeast        Married                     3
# 4       59  Female  Southeast      Unmarried                     0
# ...    ...     ...        ...            ...                   ...
# 25297   60  Female  Northwest        Married                     3
# 25298   40  Female  Southeast      Unmarried                     0
# 25299   37  Female  Northwest      Unmarried                     0
# 25300   47  Female  Southeast        Married                     2
# 25301   48  Female  Southwest        Married                     3
#
#       BMI_Category Smoking_Status Employment_Status Income_Level  \
# 0           Normal     No Smoking     Self-Employed    10L - 25L
# 1          Obesity     Occasional     Self-Employed    10L - 25L
# 2           Normal        Regular     Self-Employed         <10L
# 3       Overweight        Regular          Salaried        > 40L
# 4       Overweight     No Smoking        Freelancer    10L - 25L
# ...            ...            ...               ...          ...
# 25297       Normal     No Smoking     Self-Employed    25L - 40L
# 25298   Overweight        Regular          Salaried    10L - 25L
# 25299      Obesity     No Smoking          Salaried         <10L
# 25300       Normal     No Smoking          Salaried        > 40L
# 25301       Normal     Occasional     Self-Employed         <10L
#
#        Income_Lakhs                 Medical History  Insurance_Plan  \
# 0                20             High blood pressure               2
# 1                14                        Diabetes               1
# 2                 4  Diabetes & High blood pressure               2
# 3                46                         Thyroid               3
# 4                21                      No Disease               3
# ...             ...                             ...             ...
# 25297            26             High blood pressure               3
# 25298            16              Diabetes & Thyroid               3
# 25299             4                      No Disease               1
# 25300            82                         Thyroid               3
# 25301             7                        Diabetes               2
#
#        Annual_Premium_Amount             disease1              disease2  \
# 0                      18164  high blood pressure                  none
# 1                      15610             diabetes                  none
# 2                      20653            diabetes    high blood pressure
# 3                      26926              thyroid                  none
# 4                      26101           no disease                  none
# ...                      ...                  ...                   ...
# 25297                  26370  high blood pressure                  none
# 25298                  29496            diabetes                thyroid
# 25299                  10957           no disease                  none
# 25300                  27076              thyroid                  none
# 25301                  19730             diabetes                  none
#
#       total_risk_score  normalized_score
# 0                  0.0               NaN
# 1                  6.0             0.750
# 2                  0.0               NaN
# 3                  5.0             0.625
# 4                  0.0             0.000
# ...                ...               ...
# 25297              0.0               NaN
# 25298              0.0               NaN
# 25299              0.0             0.000
# 25300              5.0             0.625
# 25301              6.0             0.750
#
# [25223 rows x 17 columns]

# %%
df2['Income_Level']=df2['Income_Level'].map({'<10L':1,'10L - 25L':2,'25L - 40L':3,'> 40L':4})

# %%
df2.sample(5)
# Out:
#        Age  Gender     Region Marital_status  Number Of Dependants  \
# 12106   43  Female  Southeast        Married                     3
# 5547    42    Male  Northwest        Married                     3
# 1630    35  Female  Southeast        Married                     3
# 5573    32    Male  Northwest      Unmarried                     0
# 4200    65    Male  Southeast        Married                     1
#
#       BMI_Category Smoking_Status Employment_Status  Income_Level  \
# 12106       Normal     Occasional          Salaried             1
# 5547        Normal     No Smoking          Salaried             3
# 1630    Overweight     Occasional        Freelancer             3
# 5573        Normal        Regular          Salaried             1
# 4200        Normal        Regular     Self-Employed             4
#
#        Income_Lakhs           Medical History  Insurance_Plan  \
# 12106             6                  Diabetes               1
# 5547             28                No Disease               2
# 1630             38                   Thyroid               2
# 5573              1       High blood pressure               2
# 4200             58  Diabetes & Heart disease               3
#
#        Annual_Premium_Amount             disease1        disease2  \
# 12106                   9601             diabetes            none
# 5547                   13701           no disease            none
# 1630                   18641              thyroid            none
# 5573                   18724  high blood pressure            none
# 4200                   39543            diabetes    heart disease
#
#       total_risk_score  normalized_score
# 12106              6.0             0.750
# 5547               0.0             0.000
# 1630               5.0             0.625
# 5573               0.0               NaN
# 4200               0.0               NaN

# %%
nominal_columns=['Gender','Region','Marital_status','BMI_Category','Smoking_Status','Employment_Status']
df3=pd.get_dummies(df2,columns=nominal_columns,dtype=int,drop_first=True)

# %%
df3.sample(5)
# Out:
#       Age  Number Of Dependants  Income_Level  Income_Lakhs Medical History  \
# 1455   35                     1             2            17        Diabetes
# 1237   43                     0             1             3        Diabetes
# 5211   43                     1             1             5      No Disease
# 4918   44                     4             4            49   Heart disease
# 1093   60                     2             4            40        Diabetes
#
#       Insurance_Plan  Annual_Premium_Amount       disease1 disease2  \
# 1455               1                  10347       diabetes     none
# 1237               1                  13412       diabetes     none
# 5211               1                   6538     no disease     none
# 4918               2                  22782  heart disease     none
# 1093               1                  11335       diabetes     none
#
#      total_risk_score  ...  Region_Southeast  Region_Southwest  \
# 1455              6.0  ...                 0                 0
# 1237              6.0  ...                 0                 0
# 5211              0.0  ...                 0                 1
# 4918              8.0  ...                 0                 0
# 1093              6.0  ...                 1                 0
#
#       Marital_status_Unmarried  BMI_Category_Obesity  BMI_Category_Overweight  \
# 1455                         1                     0                        0
# 1237                         1                     1                        0
# 5211                         1                     0                        0
# 4918                         0                     0                        0
# 1093                         0                     0                        0
#
#       BMI_Category_Underweight  Smoking_Status_Occasional  \
# 1455                         1                          1
# 1237                         0                          0
# 5211                         0                          0
# 4918                         1                          0
# 1093                         1                          0
#
#       Smoking_Status_Regular  Employment_Status_Salaried  \
# 1455                       0                           1
# 1237                       0                           1
# 5211                       0                           0
# 4918                       1                           1
# 1093                       0                           0
#
#       Employment_Status_Self-Employed
# 1455                                0
# 1237                                0
# 5211                                0
# 4918                                0
# 1093                                1
#
# [5 rows x 23 columns]

# %%
#deleting of unnecessary columns from the data set which doesnt inpact in the model training
df4=df3.drop(['Medical History','disease1','disease2','total_risk_score'],axis=1)

# %%
df4
# Out:
#        Age  Number Of Dependants  Income_Level  Income_Lakhs  Insurance_Plan  \
# 0       49                     2             2            20               2
# 1       56                     3             2            14               1
# 2       33                     3             1             4               2
# 3       43                     3             4            46               3
# 4       59                     0             2            21               3
# ...    ...                   ...           ...           ...             ...
# 25297   60                     3             3            26               3
# 25298   40                     0             2            16               3
# 25299   37                     0             1             4               1
# 25300   47                     2             4            82               3
# 25301   48                     3             1             7               2
#
#        Annual_Premium_Amount  normalized_score  Gender_Male  Region_Northwest  \
# 0                      18164               NaN            0                 0
# 1                      15610             0.750            1                 0
# 2                      20653               NaN            1                 0
# 3                      26926             0.625            1                 0
# 4                      26101             0.000            0                 0
# ...                      ...               ...          ...               ...
# 25297                  26370               NaN            0                 1
# 25298                  29496               NaN            0                 0
# 25299                  10957             0.000            0                 1
# 25300                  27076             0.625            0                 0
# 25301                  19730             0.750            0                 0
#
#        Region_Southeast  Region_Southwest  Marital_status_Unmarried  \
# 0                     0                 0                         0
# 1                     0                 0                         0
# 2                     1                 0                         0
# 3                     0                 0                         0
# 4                     1                 0                         1
# ...                 ...               ...                       ...
# 25297                 0                 0                         0
# 25298                 1                 0                         1
# 25299                 0                 0                         1
# 25300                 1                 0                         0
# 25301                 0                 1                         0
#
#        BMI_Category_Obesity  BMI_Category_Overweight  \
# 0                         0                        0
# 1                         1                        0
# 2                         0                        0
# 3                         0                        1
# 4                         0                        1
# ...                     ...                      ...
# 25297                     0                        0
# 25298                     0                        1
# 25299                     1                        0
# 25300                     0                        0
# 25301                     0                        0
#
#        BMI_Category_Underweight  Smoking_Status_Occasional  \
# 0                             0                          0
# 1                             0                          1
# 2                             0                          0
# 3                             0                          0
# 4                             0                          0
# ...                         ...                        ...
# 25297                         0                          0
# 25298                         0                          0
# 25299                         0                          0
# 25300                         0                          0
# 25301                         0                          1
#
#        Smoking_Status_Regular  Employment_Status_Salaried  \
# 0                           0                           0
# 1                           0                           0
# 2                           1                           0
# 3                           1                           1
# 4                           0                           0
# ...                       ...                         ...
# 25297                       0                           0
# 25298                       1                           1
# 25299                       0                           1
# 25300                       0                           1
# 25301                       0                           0
#
#        Employment_Status_Self-Employed
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    0
# 4                                    0
# ...                                ...
# 25297                                1
# 25298                                0
# 25299                                0
# 25300                                0
# 25301                                1
#
# [25223 rows x 19 columns]

# %%
cm = df4.corr()

plt.figure(figsize=(20, 12))  
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45,ha='right')
plt.yticks(rotation=0)
plt.title("Correlation Matrix")
plt.tight_layout
plt.show()

# %%
df4.sample(5)
# Out:
#        Age  Number Of Dependants  Income_Level  Income_Lakhs  Insurance_Plan  \
# 23814   51                     3             1             4               2
# 12436   59                     2             1             6               2
# 9882    58                     4             1             7               1
# 22778   46                     3             3            25               3
# 14523   33                     2             1             5               2
#
#        Annual_Premium_Amount  normalized_score  Gender_Male  Region_Northwest  \
# 23814                  25810             0.750            1                 0
# 12436                  19527             0.625            0                 0
# 9882                   12864             0.750            0                 0
# 22778                  28888               NaN            0                 1
# 14523                  18678             0.750            1                 0
#
#        Region_Southeast  Region_Southwest  Marital_status_Unmarried  \
# 23814                 1                 0                         0
# 12436                 0                 1                         0
# 9882                  1                 0                         0
# 22778                 0                 0                         0
# 14523                 1                 0                         0
#
#        BMI_Category_Obesity  BMI_Category_Overweight  \
# 23814                     1                        0
# 12436                     0                        0
# 9882                      0                        1
# 22778                     0                        0
# 14523                     0                        0
#
#        BMI_Category_Underweight  Smoking_Status_Occasional  \
# 23814                         0                          0
# 12436                         1                          0
# 9882                          0                          0
# 22778                         0                          0
# 14523                         0                          0
#
#        Smoking_Status_Regular  Employment_Status_Salaried  \
# 23814                       1                           1
# 12436                       0                           1
# 9882                        0                           0
# 22778                       0                           1
# 14523                       1                           1
#
#        Employment_Status_Self-Employed
# 23814                                0
# 12436                                0
# 9882                                 1
# 22778                                0
# 14523                                0

# %%
df4 #final dataframe
# Out:
#        Age  Number Of Dependants  Income_Level  Income_Lakhs  Insurance_Plan  \
# 0       49                     2             2            20               2
# 1       56                     3             2            14               1
# 2       33                     3             1             4               2
# 3       43                     3             4            46               3
# 4       59                     0             2            21               3
# ...    ...                   ...           ...           ...             ...
# 25297   60                     3             3            26               3
# 25298   40                     0             2            16               3
# 25299   37                     0             1             4               1
# 25300   47                     2             4            82               3
# 25301   48                     3             1             7               2
#
#        Annual_Premium_Amount  normalized_score  Gender_Male  Region_Northwest  \
# 0                      18164               NaN            0                 0
# 1                      15610             0.750            1                 0
# 2                      20653               NaN            1                 0
# 3                      26926             0.625            1                 0
# 4                      26101             0.000            0                 0
# ...                      ...               ...          ...               ...
# 25297                  26370               NaN            0                 1
# 25298                  29496               NaN            0                 0
# 25299                  10957             0.000            0                 1
# 25300                  27076             0.625            0                 0
# 25301                  19730             0.750            0                 0
#
#        Region_Southeast  Region_Southwest  Marital_status_Unmarried  \
# 0                     0                 0                         0
# 1                     0                 0                         0
# 2                     1                 0                         0
# 3                     0                 0                         0
# 4                     1                 0                         1
# ...                 ...               ...                       ...
# 25297                 0                 0                         0
# 25298                 1                 0                         1
# 25299                 0                 0                         1
# 25300                 1                 0                         0
# 25301                 0                 1                         0
#
#        BMI_Category_Obesity  BMI_Category_Overweight  \
# 0                         0                        0
# 1                         1                        0
# 2                         0                        0
# 3                         0                        1
# 4                         0                        1
# ...                     ...                      ...
# 25297                     0                        0
# 25298                     0                        1
# 25299                     1                        0
# 25300                     0                        0
# 25301                     0                        0
#
#        BMI_Category_Underweight  Smoking_Status_Occasional  \
# 0                             0                          0
# 1                             0                          1
# 2                             0                          0
# 3                             0                          0
# 4                             0                          0
# ...                         ...                        ...
# 25297                         0                          0
# 25298                         0                          0
# 25299                         0                          0
# 25300                         0                          0
# 25301                         0                          1
#
#        Smoking_Status_Regular  Employment_Status_Salaried  \
# 0                           0                           0
# 1                           0                           0
# 2                           1                           0
# 3                           1                           1
# 4                           0                           0
# ...                       ...                         ...
# 25297                       0                           0
# 25298                       1                           1
# 25299                       0                           1
# 25300                       0                           1
# 25301                       0                           0
#
#        Employment_Status_Self-Employed
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    0
# 4                                    0
# ...                                ...
# 25297                                1
# 25298                                0
# 25299                                0
# 25300                                0
# 25301                                1
#
# [25223 rows x 19 columns]

# %%
X=df4.drop('Annual_Premium_Amount',axis=1)
y=df4['Annual_Premium_Amount']

# %%
df4.head(1)
# Out:
#    Age  Number Of Dependants  Income_Level  Income_Lakhs  Insurance_Plan  \
# 0   49                     2             2            20               2
#
#    Annual_Premium_Amount  normalized_score  Gender_Male  Region_Northwest  \
# 0                  18164               NaN            0                 0
#
#    Region_Southeast  Region_Southwest  Marital_status_Unmarried  \
# 0                 0                 0                         0
#
#    BMI_Category_Obesity  BMI_Category_Overweight  BMI_Category_Underweight  \
# 0                     0                        0                         0
#
#    Smoking_Status_Occasional  Smoking_Status_Regular  \
# 0                          0                       0
#
#    Employment_Status_Salaried  Employment_Status_Self-Employed
# 0                           0                                1

# %%
#scaling the large values 


from sklearn.preprocessing import MinMaxScaler
cols_to_scale=['Age','Number Of Dependants','Income_Level','Income_Lakhs']
scalar=MinMaxScaler()



X[cols_to_scale]=scalar.fit_transform(X[cols_to_scale])

# %%
X.head(2)
# Out:
#         Age  Number Of Dependants  Income_Level  Income_Lakhs  Insurance_Plan  \
# 0  0.439024                   0.4      0.333333      0.191919               2
# 1  0.609756                   0.6      0.333333      0.131313               1
#
#    normalized_score  Gender_Male  Region_Northwest  Region_Southeast  \
# 0               NaN            0                 0                 0
# 1              0.75            1                 0                 0
#
#    Region_Southwest  Marital_status_Unmarried  BMI_Category_Obesity  \
# 0                 0                         0                     0
# 1                 0                         0                     1
#
#    BMI_Category_Overweight  BMI_Category_Underweight  \
# 0                        0                         0
# 1                        0                         0
#
#    Smoking_Status_Occasional  Smoking_Status_Regular  \
# 0                          0                       0
# 1                          1                       0
#
#    Employment_Status_Salaried  Employment_Status_Self-Employed
# 0                           0                                1
# 1                           0                                1

# %%
X.describe()
# Out:
#                 Age  Number Of Dependants  Income_Level  Income_Lakhs  \
# count  25223.000000          25223.000000  25223.000000  25223.000000
# mean       0.361998              0.478611      0.373878      0.226047
# std        0.237570              0.282100      0.351692      0.227578
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.170732              0.200000      0.000000      0.060606
# 50%        0.341463              0.600000      0.333333      0.161616
# 75%        0.560976              0.600000      0.666667      0.313131
# max        1.000000              1.000000      1.000000      1.000000
#
#        Insurance_Plan  normalized_score   Gender_Male  Region_Northwest  \
# count    25223.000000      16503.000000  25223.000000      25223.000000
# mean         2.129683          0.588385      0.547992          0.200848
# std          0.757350          0.322852      0.497701          0.400643
# min          1.000000          0.000000      0.000000          0.000000
# 25%          2.000000          0.625000      0.000000          0.000000
# 50%          2.000000          0.750000      1.000000          0.000000
# 75%          3.000000          0.750000      1.000000          0.000000
# max          3.000000          1.000000      1.000000          1.000000
#
#        Region_Southeast  Region_Southwest  Marital_status_Unmarried  \
# count      25223.000000      25223.000000              25223.000000
# mean           0.352496          0.301986                  0.244737
# std            0.477757          0.459128                  0.429940
# min            0.000000          0.000000                  0.000000
# 25%            0.000000          0.000000                  0.000000
# 50%            0.000000          0.000000                  0.000000
# 75%            1.000000          1.000000                  0.000000
# max            1.000000          1.000000                  1.000000
#
#        BMI_Category_Obesity  BMI_Category_Overweight  \
# count          25223.000000             25223.000000
# mean               0.200611                 0.299211
# std                0.400465                 0.457922
# min                0.000000                 0.000000
# 25%                0.000000                 0.000000
# 50%                0.000000                 0.000000
# 75%                0.000000                 1.000000
# max                1.000000                 1.000000
#
#        BMI_Category_Underweight  Smoking_Status_Occasional  \
# count              25223.000000               25223.000000
# mean                   0.108631                   0.173096
# std                    0.311182                   0.378338
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    0.000000                   0.000000
# max                    1.000000                   1.000000
#
#        Smoking_Status_Regular  Employment_Status_Salaried  \
# count            25223.000000                25223.000000
# mean                 0.363438                    0.452365
# std                  0.480999                    0.497736
# min                  0.000000                    0.000000
# 25%                  0.000000                    0.000000
# 50%                  0.000000                    0.000000
# 75%                  1.000000                    1.000000
# max                  1.000000                    1.000000
#
#        Employment_Status_Self-Employed
# count                     25223.000000
# mean                          0.373588
# std                           0.483766
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           1.000000
# max                           1.000000

# %%
X_modified=X.drop('Income_Level',axis=1)

# %%
X_modified.head(5)
# Out:
#         Age  Number Of Dependants  Income_Lakhs  Insurance_Plan  \
# 0  0.439024                   0.4      0.191919               2
# 1  0.609756                   0.6      0.131313               1
# 2  0.048780                   0.6      0.030303               2
# 3  0.292683                   0.6      0.454545               3
# 4  0.682927                   0.0      0.202020               3
#
#    normalized_score  Gender_Male  Region_Northwest  Region_Southeast  \
# 0               NaN            0                 0                 0
# 1             0.750            1                 0                 0
# 2               NaN            1                 0                 1
# 3             0.625            1                 0                 0
# 4             0.000            0                 0                 1
#
#    Region_Southwest  Marital_status_Unmarried  BMI_Category_Obesity  \
# 0                 0                         0                     0
# 1                 0                         0                     1
# 2                 0                         0                     0
# 3                 0                         0                     0
# 4                 0                         1                     0
#
#    BMI_Category_Overweight  BMI_Category_Underweight  \
# 0                        0                         0
# 1                        0                         0
# 2                        0                         0
# 3                        1                         0
# 4                        1                         0
#
#    Smoking_Status_Occasional  Smoking_Status_Regular  \
# 0                          0                       0
# 1                          1                       0
# 2                          0                       1
# 3                          0                       1
# 4                          0                       0
#
#    Employment_Status_Salaried  Employment_Status_Self-Employed
# 0                           0                                1
# 1                           0                                1
# 2                           0                                1
# 3                           1                                0
# 4                           0                                0

# %%
#model training data
X_modified
y
# Out:
# 0        18164
# 1        15610
# 2        20653
# 3        26926
# 4        26101
#          ...
# 25297    26370
# 25298    29496
# 25299    10957
# 25300    27076
# 25301    19730
# Name: Annual_Premium_Amount, Length: 25223, dtype: int64

# %% [markdown]
# MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(X_modified,y,test_size=0.3,random_state=33)

# %%
print("x_train : ",X_train.shape)
print("x_test : ",X_test.shape)
print("y_test : ",y_test.shape)
print("y_train : ",y_train.shape)
# Out:
# x_train :  (17656, 17)
# x_test :  (7567, 17)
# y_test :  (7567,)
# y_train :  (17656,)

# %%
X_test.isnull().sum()
# Out:
# Age                                   0
# Number Of Dependants                  0
# Income_Lakhs                          0
# Insurance_Plan                        0
# normalized_score                   2577
# Gender_Male                           0
# Region_Northwest                      0
# Region_Southeast                      0
# Region_Southwest                      0
# Marital_status_Unmarried              0
# BMI_Category_Obesity                  0
# BMI_Category_Overweight               0
# BMI_Category_Underweight              0
# Smoking_Status_Occasional             0
# Smoking_Status_Regular                0
# Employment_Status_Salaried            0
# Employment_Status_Self-Employed       0
# dtype: int64

# %%
X_test['normalized_score'].fillna(0.000)
# Out:
# 25110    0.625
# 23716    0.000
# 22198    0.000
# 8255     0.750
# 23538    0.000
#          ...
# 23212    0.625
# 9499     1.000
# 24230    1.000
# 1941     0.625
# 14630    0.000
# Name: normalized_score, Length: 7567, dtype: float64

# %%
X_test.isnull().sum()
# Out:
# Age                                   0
# Number Of Dependants                  0
# Income_Lakhs                          0
# Insurance_Plan                        0
# normalized_score                   2577
# Gender_Male                           0
# Region_Northwest                      0
# Region_Southeast                      0
# Region_Southwest                      0
# Marital_status_Unmarried              0
# BMI_Category_Obesity                  0
# BMI_Category_Overweight               0
# BMI_Category_Underweight              0
# Smoking_Status_Occasional             0
# Smoking_Status_Regular                0
# Employment_Status_Salaried            0
# Employment_Status_Self-Employed       0
# dtype: int64

# %%
X_train = X_train.fillna(0.000)
X_test = X_test.fillna(0.000)   # Don't forget test data

# %%
y.describe()
# Out:
# count    25223.000000
# mean     21459.894065
# std       7022.175033
# min       6538.000000
# 25%      16056.500000
# 50%      21084.000000
# 75%      26931.000000
# max      43471.000000
# Name: Annual_Premium_Amount, dtype: float64

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#linear regression

X_train = X_train.fillna(0)
X_test = X_test.fillna(0)
training_score=model_lr.score(X_train,y_train)
testing_score=model_lr.score(X_test,y_test)
print(training_score,testing_score)
# Out:
# 0.9198211791297336 0.9181141381846032

# %%
X_test.columns
# Out:
# Index(['Age', 'Number Of Dependants', 'Income_Lakhs', 'Insurance_Plan',
#        'normalized_score', 'Gender_Male', 'Region_Northwest',
#        'Region_Southeast', 'Region_Southwest', 'Marital_status_Unmarried',
#        'BMI_Category_Obesity', 'BMI_Category_Overweight',
#        'BMI_Category_Underweight', 'Smoking_Status_Occasional',
#        'Smoking_Status_Regular', 'Employment_Status_Salaried',
#        'Employment_Status_Self-Employed'],
#       dtype='object')

# %%
model_lr.coef_
# Out:
# array([ 7.24683199e+03, -1.34792496e+03, -6.19448655e+02,  7.49757519e+03,
#         1.06764098e+03, -3.40336892e+00, -8.35424673e+01,  1.12069577e+01,
#         1.87958192e+01, -1.13288879e+03,  3.89927352e+03,  1.96332915e+03,
#         6.37036166e+02,  8.59702214e+02,  2.85888338e+03, -9.20571195e+01,
#         2.26721614e+02])

# %%
model_lr.intercept_
# Out:
# np.float64(884.604275240883)

# %%
feature_importance=model_lr.coef_
coeff_df=pd.DataFrame(feature_importance,index=X_test.columns,columns=['coefficents'])
sorted_coeff_df=coeff_df.sort_values(by='coefficents',ascending=False)

# %%
plt.figure(figsize=(8, 4))
plt.barh(sorted_coeff_df.index,sorted_coeff_df['coefficents'])
plt.xlabel('coefficient values')
plt.ylabel('feature importance')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ridge regression
from sklearn.linear_model import Ridge
model_ridge=Ridge()
model_ridge.fit(X_train,y_train)
training_score=model_ridge.score(X_train,y_train)
testing_score=model_ridge.score(X_test,y_test)
training_score,testing_score
# Out:
# (0.9198210868823279, 0.9181130797330967)

# %%
# !pip uninstall xgboost -y
# !pip install xgboost --no-cache-dir
# Out:
# Found existing installation: xgboost 3.1.0
# Uninstalling xgboost-3.1.0:
#   Successfully uninstalled xgboost-3.1.0
# Collecting xgboost
#   Downloading xgboost-3.1.0-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/venv/lib/python3.12/site-packages (from xgboost) (2.3.2)
# Requirement already satisfied: scipy in /opt/miniconda3/envs/venv/lib/python3.12/site-packages (from xgboost) (1.16.2)
# Downloading xgboost-3.1.0-py3-none-macosx_12_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.0

# %%
#xgboost

from xgboost import XGBRegressor
model_xgb=XGBRegressor()
model_xgb.fit(X_train,y_train)
training_score=model_ridge.score(X_train,y_train)
testing_score=model_ridge.score(X_test,y_test)
training_score,testing_score
# Out:
# (0.9198210868823279, 0.9181130797330967)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV

# Define model
model_xgb = XGBRegressor(random_state=42)

# Define parameter grid
param_grid = {
    'n_estimators': [20, 40, 50],        # ✅ correct name: n_estimators
    'learning_rate': [0.01, 0.1, 0.2],   # ✅ correct name: learning_rate
    'max_depth': [3, 4, 5]
}

# Define Randomized Search
random_search = RandomizedSearchCV(
    estimator=model_xgb,
    param_distributions=param_grid,
    n_iter=10,            # number of random combinations to try
    scoring='r2',        # metric to evaluate
    cv=3,                # 3-fold cross-validation
    verbose=2,
    random_state=42,
            
)

# Fit on training data
random_search.fit(X_train, y_train)

# Print best parameters and score
print("Best Parameters:", random_search.best_params_)
print("Best R2 Score:", random_search.best_score_)
print('score of the model:',random_search.score(X_train,y_train))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=20; total time=   0.0s
# Best Parameters: {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}
# Best R2 Score: 0.9644410610198975
# score of the model: 0.9654875993728638

# %%
best_model=random_search.best_estimator_
best_model.score(X_train,y_train)
# Out:
# 0.9654875993728638

# %%
feature_importance=best_model.feature_importances_


coeff_df=pd.DataFrame(feature_importance,index=X_test.columns,columns=['coefficents'])
sorted_coeff_df=coeff_df.sort_values(by='coefficents',ascending=False)
plt.figure(figsize=(8, 4))
plt.barh(sorted_coeff_df.index,sorted_coeff_df['coefficents'])
plt.xlabel('coefficient values')
plt.ylabel('feature importance')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #ERROR ANALYSIS

# %%
y_pred=best_model.predict(X_test)
residuals=y_pred-y_test
residuals_pct=residuals*100/y_test
result_df=pd.DataFrame({
    'actual' : y_test,
    'predicted' : y_pred,
    'residuals ' : residuals,
    'residuals_pct' : residuals_pct

})
